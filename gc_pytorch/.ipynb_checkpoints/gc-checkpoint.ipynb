# %%
import igl
import torch
import meshplot as mp
import numpy as np
from math import pi
from IPython.display import clear_output

# %%
v = np.array([[0, 0], [1, 0], [1, 1]])
v_d = np.array([[0, 0], [0, 1], [1, 1]])
f = np.array([[0, 1, 2]])

plt = mp.plot(v, f)
plt.update_object(oid = 0, vertices = v_d)
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(0.5, 0.5,…

# %%
# # 파일에 저장
# x = torch.tensor([0, 1, 2, 3, 4])
# torch.save(x, 'tensor.pt')

x = torch.tensor([1, 2], dtype = float)
y = torch.tensor([2, 5], dtype = float)
z = x+y
print(z)
x[0] = 3
print(x)
print(z)
# print(x[1])
# print(y[1])
print(z)
# print(z.T)
# print(x@y.T)
# print(x.device)
# print(y.device)
# print(z.device)
# Out:
# tensor([3., 7.], dtype=torch.float64)
# tensor([3., 2.], dtype=torch.float64)
# tensor([3., 7.], dtype=torch.float64)
# tensor([3., 7.], dtype=torch.float64)

# %%
# with np.load('data/octa_sphere_5.npz') as npl:
#     v_s, f_s = npl['v'], npl['f']

# #Mesh
# v_m, f_m = igl.read_triangle_mesh("data/deer.obj")
# # v_m, f_m = igl.read_triangle_mesh("data/cat.obj")
# # v_m, f_m = igl.read_triangle_mesh("data/Beast.obj")

# #Cage
# v_c, f_c = igl.read_triangle_mesh("data/deer_cage.obj")
# # v_c, f_c = igl.read_triangle_mesh("data/cat_cage.obj")
# # v_c, f_c = igl.read_triangle_mesh("data/cc_part.obj")
# # v_c, f_c = igl.read_triangle_mesh("data/Beast_Cage.obj")

# # plt = mp.plot(v_m, f_m)



# n = igl.per_face_normals( v_c, f_c, np.array([1.0, 0, 0]) ) #normalized
# # n = torch.from_numpy(n)



# # cof = (v_c[f_c[:,1]]+v_c[f_c[:,1]]+v_c[f_c[:,1]])/3 # cage face의 center of mass


# # v_mci = np.array([0, 0, 0]) # shape vertex중 cage 안에 있는 vertex 들
# # v_mco = np.array([0, 0, 0]) # shape vertex중 cage 밖에 있는 vertex 들
# # v_mciidx = np.array([]) # cage 안에 있는 vertex 들의 index

# # for i in range(v_m.shape[0]):
# #     out = 0
# #     vtocof = cof-v_m[i]
# #     for j in range(f_c.shape[0]):
# #         if(vtocof[j]@n[j]<0):
# #             out = 1
# #             break
# #     if(out == 0):
# #         v_mci=np.vstack((v_mci, v_m[i]))
# #         v_mciidx = np.append(v_mciidx, np.array([i]))
# #     else:
# #          v_mco=np.vstack((v_mco, v_m[i]))
        
# # v_mci = v_mci[1:]
# # v_mco = v_mco[1:]

# # # plt.add_points(v_mci, shading={"point_color": "red", "point_size": 0.15})

# # f_mci = np.array([0, 0, 0]) # shape face중 cage 안에 있는 face 들
# # f_mco = np.array([0, 0, 0]) # shape face중 cage 밖에 있는 face 들
# # for i in range(f_m.shape[0]):
# #     if((f_m[i, 0] in v_mciidx) and (f_m[i, 1] in v_mciidx) and (f_m[i, 2] in v_mciidx)):
# #         f_mci=np.vstack((f_mci, f_m[i]))
# #     else:
# #         f_mco=np.vstack((f_mco, f_m[i]))

# # f_mci = f_mci[1:]
# # f_mco = f_mco[1:]

# # plt = mp.plot(v_m, f_mci)

# # lines_start = np.vstack( [v_c[f_c[:,0]], v_c[f_c[:,1]], v_c[f_c[:,2]]] )
# # lines_end =  np.vstack( [v_c[f_c[:,1]], v_c[f_c[:,2]], v_c[f_c[:,0]]] )


# # plt.add_lines( lines_start, lines_end, shading={"line_color": "red"});
# # plt.add_points(v_c, shading={"point_color": "green", "point_size": 0.1})

# # lines_start = np.vstack( [v_m[f_mci[:,0]], v_m[f_mci[:,1]], v_m[f_mci[:,2]]] )
# # lines_end =  np.vstack( [v_m[f_mci[:,1]], v_m[f_mci[:,2]], v_m[f_mci[:,0]]] )


# # plt.add_lines( lines_start, lines_end, shading={"line_color": "blue"})

# # lines_start = np.vstack( [v_m[f_mco[:,0]], v_m[f_mco[:,1]], v_m[f_mco[:,2]]] )
# # lines_end =  np.vstack( [v_m[f_mco[:,1]], v_m[f_mco[:,2]], v_m[f_mco[:,0]]] )


# # plt.add_lines( lines_start, lines_end, shading={"line_color": "green"})
# # # print(v_mci)

# %%
v_m, f_m = igl.read_triangle_mesh("../data/deer.obj")
v_c, f_c = igl.read_triangle_mesh("../data/deer_cage.obj") #obj 파일에는 vertex index를 1부터 표시하지만 이 함수로 표현되는 index는 0부터
n = igl.per_face_normals(v_c, f_c, np.array([1.0, 0, 0])) #normalized
# n = torch.from_numpy(n)

# %%
v_m, f_m = igl.read_triangle_mesh("../data/deer.obj")
v_c, f_c = igl.read_triangle_mesh("../data/deer_cage.obj")
n = igl.per_face_normals(v_c, f_c, np.array([1.0, 0, 0])) #normalized
n = torch.from_numpy(n)

def GCTriInt(p, v1, v2, eta):
    
    alpha = torch.acos((v2-v1)@(p-v1)/(torch.norm(v2-v1)*torch.norm(p-v1)))
    beta = torch.acos((v1-p)@(v2-p)/(torch.norm(v1-p)*torch.norm(v2-p)))
    
    #alpha(or beta) 가 거의 pi나 0에 가까울 경우 삼각형의 넓이가 거의 0 이라 적분값이 0 
    # if abs(alpha - np.pi) < EPS or abs(alpha) < EPS: return 0 
    # if abs(beta - np.pi) < EPS or abs(beta) < EPS: return 0
    
    l = (torch.norm(p-v1)**2)*(torch.sin(alpha)**2)
    c = torch.norm(p-eta)**2
    
   
    
    theta = pi - alpha
    S = torch.sin(theta)
    C = torch.cos(theta)
    
    d1 = torch.sqrt(l + c*(S**2))
    d2 = c*(1+C)+l+torch.sqrt(l**2+l*c*(S**2))
    
    I1 = -(1/2)*torch.sign(S)*(2*torch.sqrt(c)*torch.atan(torch.sqrt(c)*C/d1)
                               + torch.sqrt(l)*torch.log(2*torch.sqrt(l)*(S**2)*(1-2*c*C/d2)/((1-C)**2)))
    
    theta = pi - alpha - beta
    S = torch.sin(theta)
    C = torch.cos(theta)
    
    d1 = torch.sqrt(l + c*(S**2))
    d2 = c*(1+C)+l+torch.sqrt(l**2+l*c*(S**2))
    
    I2 = -(1/2)*torch.sign(S)*(2*torch.sqrt(c)*torch.atan(torch.sqrt(c)*C/d1)
                               + torch.sqrt(l)*torch.log(2*torch.sqrt(l)*(S**2)*(1-2*c*C/d2)/((1-C)**2)))

    
    return -(1/(4*pi))*abs(I1-I2-torch.sqrt(c)*beta) # Why abs?




def genCoords(V, T, v_m):
    # Input (tensor)
    # V : (cv, 3) (cv: # of cage vertex) - cage vertices (sorted by ID)
    # T : (cf, 3) (cf: # of cage face) - vertices IDs of faces
    # v_m : (n, 3) (n: # of shape vertex) - vertices of shape
    
    # Output
    # phi : (n, cv) : coordinate about cage's vertex 
    # psi : (n, cf) : coordinate about cage's face's normal
    
    phi = torch.zeros(len(v_m), len(V))
    psi = torch.zeros(len(v_m), len(T))
    for eta_idx, eta in enumerate(v_m):
        clear_output(wait=True)
        print(eta_idx+1,"/",len(v_m)," ", (eta_idx+1)/len(v_m)*100,"%")
        for f_idx, f in enumerate(T):
            v = torch.tensor([V[f[0]], V[f[1]], V[f[2]]], dtype = float)
            # print("v")
            # print(v)
            # print("eta")
            # print(eta)
            for l in range(3):
                v[l] -= eta 
            p = (v[0]@n[f_idx])*n[f_idx] 
            
            s = torch.zeros(3, dtype = float)
            I = torch.zeros(3, dtype = float)
            II = torch.zeros(3, dtype = float)
            N = torch.zeros((3, 3), dtype = float)
            
            for l in range(3):
                s[l] = torch.sign(torch.cross(v[l%3]-p, v[(l+1)%3]-p)@n[f_idx])          
                I[l] = GCTriInt(p, v[l%3], v[(l+1)%3], torch.zeros(3))              
                II[l] = GCTriInt(torch.zeros(3),  v[(l+1)%3], v[l%3], torch.zeros(3))
                q = torch.cross(v[(l+1)%3],  v[l%3])
                N[l] = q/torch.norm(q)
            
            I_f = - abs(s[0]*I[0]+s[1]*I[1]+s[2]*I[2])
            psi[eta_idx, f_idx] = -I_f
            w = I_f*n[f_idx] + II[0]*N[0]+II[1]*N[1]+II[2]*N[2]
            
            if(torch.norm(w) > 0.00001):
                for l in range(3):
                    phi[eta_idx, f[l]] += (N[(l+1)%3]@w)/(N[(l+1)%3]@v[l]) #하나의 face의 한 꼭짓점에 대한 phi component 계산값을 하나씩 축적해줌                 
    
    return psi, phi


v_m = torch.from_numpy(v_m)
psi, phi = genCoords(v_c, f_c, v_m) #psi : for face's normal, phi: for vertex
# Out:
# 1 / 772   0.1295336787564767 %
# term1
# tensor(3.3239, dtype=torch.float64)
# term2
# tensor(0.4850, dtype=torch.float64)
# I1
# tensor(-1.9044, dtype=torch.float64)
# term1
# tensor(3.4461, dtype=torch.float64)
# term2
# tensor(0.6225, dtype=torch.float64)
# I2
# tensor(-2.0343, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-1.2723, dtype=torch.float64)
# I1
# tensor(0.6362, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-0.7408, dtype=torch.float64)
# I2
# tensor(0.3704, dtype=torch.float64)
# term1
# tensor(-0.4076, dtype=torch.float64)
# term2
# tensor(1.3875, dtype=torch.float64)
# I1
# tensor(-0.4899, dtype=torch.float64)
# term1
# tensor(0.4082, dtype=torch.float64)
# term2
# tensor(2.5255, dtype=torch.float64)
# I2
# tensor(-1.4669, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(2.4153, dtype=torch.float64)
# I1
# tensor(-1.2076, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.9118, dtype=torch.float64)
# I2
# tensor(-1.9559, dtype=torch.float64)
# term1
# tensor(-1.3605, dtype=torch.float64)
# term2
# tensor(-0.1445, dtype=torch.float64)
# I1
# tensor(0.7525, dtype=torch.float64)
# term1
# tensor(-0.3602, dtype=torch.float64)
# term2
# tensor(0.9328, dtype=torch.float64)
# I2
# tensor(-0.2863, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.0307, dtype=torch.float64)
# I1
# tensor(-1.5154, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(4.6147, dtype=torch.float64)
# I2
# tensor(-2.3074, dtype=torch.float64)
# term1
# tensor(0.3602, dtype=torch.float64)
# term2
# tensor(1.5591, dtype=torch.float64)
# I1
# tensor(-0.9597, dtype=torch.float64)
# term1
# tensor(1.3605, dtype=torch.float64)
# term2
# tensor(2.6364, dtype=torch.float64)
# I2
# tensor(-1.9984, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(0.5257, dtype=torch.float64)
# I1
# tensor(-0.2628, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(2.1097, dtype=torch.float64)
# I2
# tensor(-1.0548, dtype=torch.float64)
# term1
# tensor(-3.4448, dtype=torch.float64)
# term2
# tensor(-0.8378, dtype=torch.float64)
# I1
# tensor(2.1413, dtype=torch.float64)
# term1
# tensor(-3.3225, dtype=torch.float64)
# term2
# tensor(-0.7001, dtype=torch.float64)
# I2
# tensor(2.0113, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.8410, dtype=torch.float64)
# I1
# tensor(-1.9205, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(4.3726, dtype=torch.float64)
# I2
# tensor(-2.1863, dtype=torch.float64)
# term1
# tensor(-0.5972, dtype=torch.float64)
# term2
# tensor(0.6783, dtype=torch.float64)
# I1
# tensor(-0.0406, dtype=torch.float64)
# term1
# tensor(0.5964, dtype=torch.float64)
# term2
# tensor(1.6799, dtype=torch.float64)
# I2
# tensor(-1.1382, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(1.7696, dtype=torch.float64)
# I1
# tensor(-0.8848, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.2639, dtype=torch.float64)
# I2
# tensor(-1.6319, dtype=torch.float64)
# term1
# tensor(-0.1331, dtype=torch.float64)
# term2
# tensor(-0.7820, dtype=torch.float64)
# I1
# tensor(0.4576, dtype=torch.float64)
# term1
# tensor(-0.1202, dtype=torch.float64)
# term2
# tensor(-0.4823, dtype=torch.float64)
# I2
# tensor(0.3013, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.4883, dtype=torch.float64)
# I1
# tensor(-1.7441, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.7987, dtype=torch.float64)
# I2
# tensor(-1.8994, dtype=torch.float64)
# term1
# tensor(-0.4765, dtype=torch.float64)
# term2
# tensor(-1.6907, dtype=torch.float64)
# I1
# tensor(1.0836, dtype=torch.float64)
# term1
# tensor(-0.4549, dtype=torch.float64)
# term2
# tensor(-1.3630, dtype=torch.float64)
# I2
# tensor(0.9090, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(1.8296, dtype=torch.float64)
# I1
# tensor(-0.9148, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.2453, dtype=torch.float64)
# I2
# tensor(-1.1227, dtype=torch.float64)
# term1
# tensor(0.9499, dtype=torch.float64)
# term2
# tensor(0.2597, dtype=torch.float64)
# I1
# tensor(-0.6048, dtype=torch.float64)
# term1
# tensor(0.9554, dtype=torch.float64)
# term2
# tensor(0.3493, dtype=torch.float64)
# I2
# tensor(-0.6524, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-1.8757, dtype=torch.float64)
# I1
# tensor(0.9379, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-1.5678, dtype=torch.float64)
# I2
# tensor(0.7839, dtype=torch.float64)
# term1
# tensor(-0.9554, dtype=torch.float64)
# term2
# tensor(-0.6867, dtype=torch.float64)
# I1
# tensor(0.8211, dtype=torch.float64)
# term1
# tensor(-0.9499, dtype=torch.float64)
# term2
# tensor(-0.5972, dtype=torch.float64)
# I2
# tensor(0.7735, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(1.3789, dtype=torch.float64)
# I1
# tensor(-0.6895, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(1.6868, dtype=torch.float64)
# I2
# tensor(-0.8434, dtype=torch.float64)
# term1
# tensor(0.5502, dtype=torch.float64)
# term2
# tensor(1.0769, dtype=torch.float64)
# I1
# tensor(-0.8135, dtype=torch.float64)
# term1
# tensor(0.5615, dtype=torch.float64)
# term2
# tensor(1.2296, dtype=torch.float64)
# I2
# tensor(-0.8956, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-1.8301, dtype=torch.float64)
# I1
# tensor(0.9150, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-1.6159, dtype=torch.float64)
# I2
# tensor(0.8079, dtype=torch.float64)
# term1
# tensor(0.3444, dtype=torch.float64)
# term2
# tensor(1.9946, dtype=torch.float64)
# I1
# tensor(-1.1695, dtype=torch.float64)
# term1
# tensor(0.3588, dtype=torch.float64)
# term2
# tensor(2.2833, dtype=torch.float64)
# I2
# tensor(-1.3210, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-2.0724, dtype=torch.float64)
# I1
# tensor(1.0362, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-1.7410, dtype=torch.float64)
# I2
# tensor(0.8705, dtype=torch.float64)
# term1
# tensor(-0.0803, dtype=torch.float64)
# term2
# tensor(0.2587, dtype=torch.float64)
# I1
# tensor(-0.0892, dtype=torch.float64)
# term1
# tensor(-0.0323, dtype=torch.float64)
# term2
# tensor(1.6019, dtype=torch.float64)
# I2
# tensor(-0.7848, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.2657, dtype=torch.float64)
# I1
# tensor(-1.6328, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(4.6369, dtype=torch.float64)
# I2
# tensor(-2.3184, dtype=torch.float64)
# term1
# tensor(-0.3588, dtype=torch.float64)
# term2
# tensor(-1.8975, dtype=torch.float64)
# I1
# tensor(1.1281, dtype=torch.float64)
# term1
# tensor(-0.3444, dtype=torch.float64)
# term2
# tensor(-1.6087, dtype=torch.float64)
# I2
# tensor(0.9766, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.3953, dtype=torch.float64)
# I1
# tensor(-1.1976, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.7267, dtype=torch.float64)
# I2
# tensor(-1.3634, dtype=torch.float64)
# term1
# tensor(0.1806, dtype=torch.float64)
# term2
# tensor(2.6463, dtype=torch.float64)
# I1
# tensor(-1.4135, dtype=torch.float64)
# term1
# tensor(0.2203, dtype=torch.float64)
# term2
# tensor(3.5469, dtype=torch.float64)
# I2
# tensor(-1.8836, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-1.9720, dtype=torch.float64)
# I1
# tensor(0.9860, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-1.0173, dtype=torch.float64)
# I2
# tensor(0.5087, dtype=torch.float64)
# term1
# tensor(-0.2203, dtype=torch.float64)
# term2
# tensor(-1.9226, dtype=torch.float64)
# I1
# tensor(1.0714, dtype=torch.float64)
# term1
# tensor(-0.1806, dtype=torch.float64)
# term2
# tensor(-1.0221, dtype=torch.float64)
# I2
# tensor(0.6013, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.8717, dtype=torch.float64)
# I1
# tensor(-1.4358, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.8264, dtype=torch.float64)
# I2
# tensor(-1.9132, dtype=torch.float64)
# term1
# tensor(0.0560, dtype=torch.float64)
# term2
# tensor(2.4384, dtype=torch.float64)
# I1
# tensor(-1.2472, dtype=torch.float64)
# term1
# tensor(0.1196, dtype=torch.float64)
# term2
# tensor(3.6987, dtype=torch.float64)
# I2
# tensor(-1.9092, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-0.5342, dtype=torch.float64)
# I1
# tensor(0.2671, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(0.7671, dtype=torch.float64)
# I2
# tensor(-0.3835, dtype=torch.float64)
# term1
# tensor(0.1313, dtype=torch.float64)
# term2
# tensor(3.6613, dtype=torch.float64)
# I1
# tensor(-1.8963, dtype=torch.float64)
# term1
# tensor(0.1492, dtype=torch.float64)
# term2
# tensor(4.1747, dtype=torch.float64)
# I2
# tensor(-2.1619, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-1.2721, dtype=torch.float64)
# I1
# tensor(0.6361, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-0.7405, dtype=torch.float64)
# I2
# tensor(0.3703, dtype=torch.float64)
# term1
# tensor(-0.1193, dtype=torch.float64)
# term2
# tensor(-0.5644, dtype=torch.float64)
# I1
# tensor(0.3419, dtype=torch.float64)
# term1
# tensor(-0.0559, dtype=torch.float64)
# term2
# tensor(0.6959, dtype=torch.float64)
# I2
# tensor(-0.3200, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.5661, dtype=torch.float64)
# I1
# tensor(-1.2831, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.8675, dtype=torch.float64)
# I2
# tensor(-1.9337, dtype=torch.float64)
# term1
# tensor(0.3435, dtype=torch.float64)
# term2
# tensor(1.9950, dtype=torch.float64)
# I1
# tensor(-1.1693, dtype=torch.float64)
# term1
# tensor(0.3579, dtype=torch.float64)
# term2
# tensor(2.2837, dtype=torch.float64)
# I2
# tensor(-1.3208, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-2.0724, dtype=torch.float64)
# I1
# tensor(1.0362, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-1.7411, dtype=torch.float64)
# I2
# tensor(0.8705, dtype=torch.float64)
# term1
# tensor(-0.0330, dtype=torch.float64)
# term2
# tensor(1.5818, dtype=torch.float64)
# I1
# tensor(-0.7744, dtype=torch.float64)
# term1
# tensor(0.0378, dtype=torch.float64)
# term2
# tensor(3.2938, dtype=torch.float64)
# I2
# tensor(-1.6658, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(1.5298, dtype=torch.float64)
# I1
# tensor(-0.7649, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.2775, dtype=torch.float64)
# I2
# tensor(-1.6387, dtype=torch.float64)
# term1
# tensor(-0.0378, dtype=torch.float64)
# term2
# tensor(1.4608, dtype=torch.float64)
# I1
# tensor(-0.7115, dtype=torch.float64)
# term1
# tensor(0.0330, dtype=torch.float64)
# term2
# tensor(3.1728, dtype=torch.float64)
# I2
# tensor(-1.6029, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(1.6533, dtype=torch.float64)
# I1
# tensor(-0.8266, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.4010, dtype=torch.float64)
# I2
# tensor(-1.7005, dtype=torch.float64)
# term1
# tensor(0.0323, dtype=torch.float64)
# term2
# tensor(3.1612, dtype=torch.float64)
# I1
# tensor(-1.5967, dtype=torch.float64)
# term1
# tensor(0.0801, dtype=torch.float64)
# term2
# tensor(4.5045, dtype=torch.float64)
# I2
# tensor(-2.2923, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(0.3025, dtype=torch.float64)
# I1
# tensor(-0.1512, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(1.6737, dtype=torch.float64)
# I2
# tensor(-0.8368, dtype=torch.float64)
# term1
# tensor(-0.1488, dtype=torch.float64)
# term2
# tensor(-1.2776, dtype=torch.float64)
# I1
# tensor(0.7132, dtype=torch.float64)
# term1
# tensor(-0.1309, dtype=torch.float64)
# term2
# tensor(-0.7642, dtype=torch.float64)
# I2
# tensor(0.4475, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.8407, dtype=torch.float64)
# I1
# tensor(-1.9203, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(4.3722, dtype=torch.float64)
# I2
# tensor(-2.1861, dtype=torch.float64)
# term1
# tensor(-4.3871, dtype=torch.float64)
# term2
# tensor(-0.5425, dtype=torch.float64)
# I1
# tensor(2.4648, dtype=torch.float64)
# term1
# tensor(-2.9196, dtype=torch.float64)
# term2
# tensor(-0.2672, dtype=torch.float64)
# I2
# tensor(1.5934, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.2654, dtype=torch.float64)
# I1
# tensor(-1.6327, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(4.6366, dtype=torch.float64)
# I2
# tensor(-2.3183, dtype=torch.float64)
# term1
# tensor(-2.6820, dtype=torch.float64)
# term2
# tensor(-0.2480, dtype=torch.float64)
# I1
# tensor(1.4650, dtype=torch.float64)
# term1
# tensor(2.6844, dtype=torch.float64)
# term2
# tensor(0.0712, dtype=torch.float64)
# I2
# tensor(-1.3778, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(1.7341, dtype=torch.float64)
# I1
# tensor(-0.8671, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.2282, dtype=torch.float64)
# I2
# tensor(-1.6141, dtype=torch.float64)
# term1
# tensor(0.0931, dtype=torch.float64)
# term2
# tensor(0.0604, dtype=torch.float64)
# I1
# tensor(-0.0768, dtype=torch.float64)
# term1
# tensor(3.7420, dtype=torch.float64)
# term2
# tensor(0.6397, dtype=torch.float64)
# I2
# tensor(-2.1908, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(0.5225, dtype=torch.float64)
# I1
# tensor(-0.2612, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(2.5395, dtype=torch.float64)
# I2
# tensor(-1.2697, dtype=torch.float64)
# term1
# tensor(-3.7420, dtype=torch.float64)
# term2
# tensor(-0.5357, dtype=torch.float64)
# I1
# tensor(2.1388, dtype=torch.float64)
# term1
# tensor(-0.0931, dtype=torch.float64)
# term2
# tensor(0.0437, dtype=torch.float64)
# I2
# tensor(0.0247, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.5978, dtype=torch.float64)
# I1
# tensor(-1.2989, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(4.6149, dtype=torch.float64)
# I2
# tensor(-2.3074, dtype=torch.float64)
# term1
# tensor(2.9170, dtype=torch.float64)
# term2
# tensor(0.0530, dtype=torch.float64)
# I1
# tensor(-1.4850, dtype=torch.float64)
# term1
# tensor(4.3853, dtype=torch.float64)
# term2
# tensor(0.3287, dtype=torch.float64)
# I2
# tensor(-2.3570, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(0.3027, dtype=torch.float64)
# I1
# tensor(-0.1514, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(1.6739, dtype=torch.float64)
# I2
# tensor(-0.8370, dtype=torch.float64)
# term1
# tensor(-0.9823, dtype=torch.float64)
# term2
# tensor(0.5522, dtype=torch.float64)
# I1
# tensor(0.2151, dtype=torch.float64)
# term1
# tensor(0.9811, dtype=torch.float64)
# term2
# tensor(1.3450, dtype=torch.float64)
# I2
# tensor(-1.1631, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(2.4163, dtype=torch.float64)
# I1
# tensor(-1.2082, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.9128, dtype=torch.float64)
# I2
# tensor(-1.9564, dtype=torch.float64)
# term1
# tensor(-3.4448, dtype=torch.float64)
# term2
# tensor(-0.6558, dtype=torch.float64)
# I1
# tensor(2.0503, dtype=torch.float64)
# term1
# tensor(-2.4667, dtype=torch.float64)
# term2
# tensor(-0.3313, dtype=torch.float64)
# I2
# tensor(1.3990, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.5664, dtype=torch.float64)
# I1
# tensor(-1.2832, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.8678, dtype=torch.float64)
# I2
# tensor(-1.9339, dtype=torch.float64)
# term1
# tensor(-1.9066, dtype=torch.float64)
# term2
# tensor(-0.2637, dtype=torch.float64)
# I1
# tensor(1.0852, dtype=torch.float64)
# term1
# tensor(1.9048, dtype=torch.float64)
# term2
# tensor(0.1804, dtype=torch.float64)
# I2
# tensor(-1.0426, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(0.9691, dtype=torch.float64)
# I1
# tensor(-0.4845, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.4583, dtype=torch.float64)
# I2
# tensor(-1.2292, dtype=torch.float64)
# term1
# tensor(0.2481, dtype=torch.float64)
# term2
# tensor(0.1366, dtype=torch.float64)
# I1
# tensor(-0.1924, dtype=torch.float64)
# term1
# tensor(2.8084, dtype=torch.float64)
# term2
# tensor(0.8704, dtype=torch.float64)
# I2
# tensor(-1.8394, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-0.2634, dtype=torch.float64)
# I1
# tensor(0.1317, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(1.7001, dtype=torch.float64)
# I2
# tensor(-0.8500, dtype=torch.float64)
# term1
# tensor(-2.8084, dtype=torch.float64)
# term2
# tensor(-0.6779, dtype=torch.float64)
# I1
# tensor(1.7432, dtype=torch.float64)
# term1
# tensor(-0.2481, dtype=torch.float64)
# term2
# tensor(0.0558, dtype=torch.float64)
# I2
# tensor(0.0961, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(1.9162, dtype=torch.float64)
# I1
# tensor(-0.9581, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.8797, dtype=torch.float64)
# I2
# tensor(-1.9398, dtype=torch.float64)
# term1
# tensor(2.4688, dtype=torch.float64)
# term2
# tensor(0.1167, dtype=torch.float64)
# I1
# tensor(-1.2927, dtype=torch.float64)
# term1
# tensor(3.4463, dtype=torch.float64)
# term2
# tensor(0.4407, dtype=torch.float64)
# I2
# tensor(-1.9435, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-0.5345, dtype=torch.float64)
# I1
# tensor(0.2672, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(0.7668, dtype=torch.float64)
# I2
# tensor(-0.3834, dtype=torch.float64)
# term1
# tensor(-0.6805, dtype=torch.float64)
# term2
# tensor(0.5779, dtype=torch.float64)
# I1
# tensor(0.0513, dtype=torch.float64)
# term1
# tensor(0.6814, dtype=torch.float64)
# term2
# tensor(1.5265, dtype=torch.float64)
# I2
# tensor(-1.1039, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(1.7686, dtype=torch.float64)
# I1
# tensor(-0.8843, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.2628, dtype=torch.float64)
# I2
# tensor(-1.6314, dtype=torch.float64)
# term1
# tensor(-0.5603, dtype=torch.float64)
# term2
# tensor(-1.4348, dtype=torch.float64)
# I1
# tensor(0.9975, dtype=torch.float64)
# term1
# tensor(-0.5490, dtype=torch.float64)
# term2
# tensor(-1.2821, dtype=torch.float64)
# I2
# tensor(0.9155, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(1.6909, dtype=torch.float64)
# I1
# tensor(-0.8455, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(1.9050, dtype=torch.float64)
# I2
# tensor(-0.9525, dtype=torch.float64)
# term1
# tensor(0.4538, dtype=torch.float64)
# term2
# tensor(1.3277, dtype=torch.float64)
# I1
# tensor(-0.8908, dtype=torch.float64)
# term1
# tensor(0.4753, dtype=torch.float64)
# term2
# tensor(1.6554, dtype=torch.float64)
# I2
# tensor(-1.0653, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-1.9995, dtype=torch.float64)
# I1
# tensor(0.9998, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-1.5840, dtype=torch.float64)
# I2
# tensor(0.7920, dtype=torch.float64)
# term1
# tensor(-0.1429, dtype=torch.float64)
# term2
# tensor(-0.8247, dtype=torch.float64)
# I1
# tensor(0.4838, dtype=torch.float64)
# term1
# tensor(-0.1138, dtype=torch.float64)
# term2
# tensor(-0.2780, dtype=torch.float64)
# I2
# tensor(0.1959, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.8884, dtype=torch.float64)
# I1
# tensor(-1.4442, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.4579, dtype=torch.float64)
# I2
# tensor(-1.7290, dtype=torch.float64)
# term1
# tensor(0.1138, dtype=torch.float64)
# term2
# tensor(2.7205, dtype=torch.float64)
# I1
# tensor(-1.4172, dtype=torch.float64)
# term1
# tensor(0.1429, dtype=torch.float64)
# term2
# tensor(3.2673, dtype=torch.float64)
# I2
# tensor(-1.7051, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-0.8043, dtype=torch.float64)
# I1
# tensor(0.4022, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-0.2348, dtype=torch.float64)
# I2
# tensor(0.1174, dtype=torch.float64)
# term1
# tensor(0.1199, dtype=torch.float64)
# term2
# tensor(3.3177, dtype=torch.float64)
# I1
# tensor(-1.7188, dtype=torch.float64)
# term1
# tensor(0.1328, dtype=torch.float64)
# term2
# tensor(3.6174, dtype=torch.float64)
# I2
# tensor(-1.8751, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-0.7595, dtype=torch.float64)
# I1
# tensor(0.3797, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-0.4490, dtype=torch.float64)
# I2
# tensor(0.2245, dtype=torch.float64)
# term1
# tensor(-0.3579, dtype=torch.float64)
# term2
# tensor(-1.8979, dtype=torch.float64)
# I1
# tensor(1.1279, dtype=torch.float64)
# term1
# tensor(-0.3435, dtype=torch.float64)
# term2
# tensor(-1.6091, dtype=torch.float64)
# I2
# tensor(0.9763, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.3947, dtype=torch.float64)
# I1
# tensor(-1.1973, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.7260, dtype=torch.float64)
# I2
# tensor(-1.3630, dtype=torch.float64)
# term1
# tensor(-3.2803, dtype=torch.float64)
# term2
# tensor(-0.7028, dtype=torch.float64)
# I1
# tensor(1.9915, dtype=torch.float64)
# term1
# tensor(-3.1748, dtype=torch.float64)
# term2
# tensor(-0.6216, dtype=torch.float64)
# I2
# tensor(1.8982, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.4880, dtype=torch.float64)
# I1
# tensor(-1.7440, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.7984, dtype=torch.float64)
# I2
# tensor(-1.8992, dtype=torch.float64)
# term1
# tensor(-0.7436, dtype=torch.float64)
# term2
# tensor(0.3482, dtype=torch.float64)
# I1
# tensor(0.1977, dtype=torch.float64)
# term1
# tensor(0.7445, dtype=torch.float64)
# term2
# tensor(1.2556, dtype=torch.float64)
# I2
# tensor(-1.0001, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(1.4419, dtype=torch.float64)
# I1
# tensor(-0.7210, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.9345, dtype=torch.float64)
# I2
# tensor(-1.4673, dtype=torch.float64)
# term1
# tensor(-0.1742, dtype=torch.float64)
# term2
# tensor(0.7958, dtype=torch.float64)
# I1
# tensor(-0.3108, dtype=torch.float64)
# term1
# tensor(1.1589, dtype=torch.float64)
# term2
# tensor(1.7548, dtype=torch.float64)
# I2
# tensor(-1.4569, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(0.9318, dtype=torch.float64)
# I1
# tensor(-0.4659, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.4559, dtype=torch.float64)
# I2
# tensor(-1.2280, dtype=torch.float64)
# term1
# tensor(-1.1589, dtype=torch.float64)
# term2
# tensor(0.0656, dtype=torch.float64)
# I1
# tensor(0.5467, dtype=torch.float64)
# term1
# tensor(0.1742, dtype=torch.float64)
# term2
# tensor(1.0246, dtype=torch.float64)
# I2
# tensor(-0.5994, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(2.0922, dtype=torch.float64)
# I1
# tensor(-1.0461, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.6164, dtype=torch.float64)
# I2
# tensor(-1.8082, dtype=torch.float64)
# term1
# tensor(3.1733, dtype=torch.float64)
# term2
# tensor(0.4080, dtype=torch.float64)
# I1
# tensor(-1.7906, dtype=torch.float64)
# term1
# tensor(3.2789, dtype=torch.float64)
# term2
# tensor(0.4892, dtype=torch.float64)
# I2
# tensor(-1.8840, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-0.7593, dtype=torch.float64)
# I1
# tensor(0.3796, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-0.4488, dtype=torch.float64)
# I2
# tensor(0.2244, dtype=torch.float64)
# term1
# tensor(-0.5911, dtype=torch.float64)
# term2
# tensor(0.6664, dtype=torch.float64)
# I1
# tensor(-0.0376, dtype=torch.float64)
# term1
# tensor(0.5904, dtype=torch.float64)
# term2
# tensor(1.6717, dtype=torch.float64)
# I2
# tensor(-1.1310, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(1.7351, dtype=torch.float64)
# I1
# tensor(-0.8676, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.2292, dtype=torch.float64)
# I2
# tensor(-1.6146, dtype=torch.float64)
# term1
# tensor(-0.5839, dtype=torch.float64)
# term2
# tensor(-1.4167, dtype=torch.float64)
# I1
# tensor(1.0003, dtype=torch.float64)
# term1
# tensor(-0.5724, dtype=torch.float64)
# term2
# tensor(-1.2665, dtype=torch.float64)
# I2
# tensor(0.9195, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(1.6918, dtype=torch.float64)
# I1
# tensor(-0.8459, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(1.9060, dtype=torch.float64)
# I2
# tensor(-0.9530, dtype=torch.float64)
# term1
# tensor(-0.0702, dtype=torch.float64)
# term2
# tensor(0.3353, dtype=torch.float64)
# I1
# tensor(-0.1326, dtype=torch.float64)
# term1
# tensor(0.0701, dtype=torch.float64)
# term2
# tensor(1.7471, dtype=torch.float64)
# I2
# tensor(-0.9086, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(0.4143, dtype=torch.float64)
# I1
# tensor(-0.2072, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(1.8967, dtype=torch.float64)
# I2
# tensor(-0.9483, dtype=torch.float64)
# term1
# tensor(0.0135, dtype=torch.float64)
# term2
# tensor(1.2906, dtype=torch.float64)
# I1
# tensor(-0.6520, dtype=torch.float64)
# term1
# tensor(0.1295, dtype=torch.float64)
# term2
# tensor(2.7235, dtype=torch.float64)
# I2
# tensor(-1.4265, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-0.3914, dtype=torch.float64)
# I1
# tensor(0.1957, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(1.1071, dtype=torch.float64)
# I2
# tensor(-0.5536, dtype=torch.float64)
# term1
# tensor(-0.1295, dtype=torch.float64)
# term2
# tensor(-0.4302, dtype=torch.float64)
# I1
# tensor(0.2799, dtype=torch.float64)
# term1
# tensor(-0.0135, dtype=torch.float64)
# term2
# tensor(1.0027, dtype=torch.float64)
# I2
# tensor(-0.4946, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(1.4081, dtype=torch.float64)
# I1
# tensor(-0.7041, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.9067, dtype=torch.float64)
# I2
# tensor(-1.4533, dtype=torch.float64)
# term1
# tensor(0.5730, dtype=torch.float64)
# term2
# tensor(1.0510, dtype=torch.float64)
# I1
# tensor(-0.8120, dtype=torch.float64)
# term1
# tensor(0.5845, dtype=torch.float64)
# term2
# tensor(1.2010, dtype=torch.float64)
# I2
# tensor(-0.8928, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-1.8299, dtype=torch.float64)
# I1
# tensor(0.9149, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-1.6158, dtype=torch.float64)
# I2
# tensor(0.8079, dtype=torch.float64)
# term1
# tensor(-0.0470, dtype=torch.float64)
# term2
# tensor(0.8905, dtype=torch.float64)
# I1
# tensor(-0.4217, dtype=torch.float64)
# term1
# tensor(0.0471, dtype=torch.float64)
# term2
# tensor(2.3325, dtype=torch.float64)
# I2
# tensor(-1.1898, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(0.9681, dtype=torch.float64)
# I1
# tensor(-0.4840, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.4573, dtype=torch.float64)
# I2
# tensor(-1.2287, dtype=torch.float64)
# term1
# tensor(1.7134, dtype=torch.float64)
# term2
# tensor(0.0525, dtype=torch.float64)
# I1
# tensor(-0.8829, dtype=torch.float64)
# term1
# tensor(3.5240, dtype=torch.float64)
# term2
# tensor(0.3109, dtype=torch.float64)
# I2
# tensor(-1.9174, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(0.6907, dtype=torch.float64)
# I1
# tensor(-0.3453, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(1.7563, dtype=torch.float64)
# I2
# tensor(-0.8781, dtype=torch.float64)
# term1
# tensor(-0.9239, dtype=torch.float64)
# term2
# tensor(0.2350, dtype=torch.float64)
# I1
# tensor(0.3444, dtype=torch.float64)
# term1
# tensor(0.7015, dtype=torch.float64)
# term2
# tensor(0.6594, dtype=torch.float64)
# I2
# tensor(-0.6805, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(2.1920, dtype=torch.float64)
# I1
# tensor(-1.0960, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.1341, dtype=torch.float64)
# I2
# tensor(-1.5670, dtype=torch.float64)
# term1
# tensor(-3.2006, dtype=torch.float64)
# term2
# tensor(-0.4062, dtype=torch.float64)
# I1
# tensor(1.8034, dtype=torch.float64)
# term1
# tensor(0.3535, dtype=torch.float64)
# term2
# tensor(0.0199, dtype=torch.float64)
# I2
# tensor(-0.1867, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(2.1719, dtype=torch.float64)
# I1
# tensor(-1.0860, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.7235, dtype=torch.float64)
# I2
# tensor(-1.8617, dtype=torch.float64)
# term1
# tensor(-0.3535, dtype=torch.float64)
# term2
# tensor(-0.0380, dtype=torch.float64)
# I1
# tensor(0.1957, dtype=torch.float64)
# term1
# tensor(3.2006, dtype=torch.float64)
# term2
# tensor(0.3881, dtype=torch.float64)
# I2
# tensor(-1.7944, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(0.8312, dtype=torch.float64)
# I1
# tensor(-0.4156, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.3827, dtype=torch.float64)
# I2
# tensor(-1.1914, dtype=torch.float64)
# term1
# tensor(-3.3686, dtype=torch.float64)
# term2
# tensor(-0.4232, dtype=torch.float64)
# I1
# tensor(1.8959, dtype=torch.float64)
# term1
# tensor(-1.3169, dtype=torch.float64)
# term2
# tensor(-0.1400, dtype=torch.float64)
# I2
# tensor(0.7285, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.6375, dtype=torch.float64)
# I1
# tensor(-1.3187, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.7425, dtype=torch.float64)
# I2
# tensor(-1.8713, dtype=torch.float64)
# term1
# tensor(-2.9079, dtype=torch.float64)
# term2
# tensor(-0.2795, dtype=torch.float64)
# I1
# tensor(1.5937, dtype=torch.float64)
# term1
# tensor(2.9056, dtype=torch.float64)
# term2
# tensor(-0.0060, dtype=torch.float64)
# I2
# tensor(-1.4498, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(1.4429, dtype=torch.float64)
# I1
# tensor(-0.7215, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.9356, dtype=torch.float64)
# I2
# tensor(-1.4678, dtype=torch.float64)
# term1
# tensor(-2.3135, dtype=torch.float64)
# term2
# tensor(-0.5302, dtype=torch.float64)
# I1
# tensor(1.4219, dtype=torch.float64)
# term1
# tensor(-2.2602, dtype=torch.float64)
# term2
# tensor(-0.4041, dtype=torch.float64)
# I2
# tensor(1.3322, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.0285, dtype=torch.float64)
# I1
# tensor(-1.0143, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.9004, dtype=torch.float64)
# I2
# tensor(-1.4502, dtype=torch.float64)
# term1
# tensor(-0.2309, dtype=torch.float64)
# term2
# tensor(0.2695, dtype=torch.float64)
# I1
# tensor(-0.0193, dtype=torch.float64)
# term1
# tensor(0.2315, dtype=torch.float64)
# term2
# tensor(0.8653, dtype=torch.float64)
# I2
# tensor(-0.5484, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(0.7183, dtype=torch.float64)
# I1
# tensor(-0.3591, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(1.5150, dtype=torch.float64)
# I2
# tensor(-0.7575, dtype=torch.float64)
# term1
# tensor(1.0286, dtype=torch.float64)
# term2
# tensor(0.9533, dtype=torch.float64)
# I1
# tensor(-0.9909, dtype=torch.float64)
# term1
# tensor(1.3621, dtype=torch.float64)
# term2
# tensor(1.7254, dtype=torch.float64)
# I2
# tensor(-1.5438, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-1.8195, dtype=torch.float64)
# I1
# tensor(0.9097, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-0.5570, dtype=torch.float64)
# I2
# tensor(0.2785, dtype=torch.float64)
# term1
# tensor(-1.3621, dtype=torch.float64)
# term2
# tensor(-1.4245, dtype=torch.float64)
# I1
# tensor(1.3933, dtype=torch.float64)
# term1
# tensor(-1.0286, dtype=torch.float64)
# term2
# tensor(-0.6524, dtype=torch.float64)
# I2
# tensor(0.8405, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.0683, dtype=torch.float64)
# I1
# tensor(-1.0342, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(3.3308, dtype=torch.float64)
# I2
# tensor(-1.6654, dtype=torch.float64)
# term1
# tensor(1.9439, dtype=torch.float64)
# term2
# tensor(0.2759, dtype=torch.float64)
# I1
# tensor(-1.1099, dtype=torch.float64)
# term1
# tensor(2.0529, dtype=torch.float64)
# term2
# tensor(0.5318, dtype=torch.float64)
# I2
# tensor(-1.2924, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-2.0301, dtype=torch.float64)
# I1
# tensor(1.0151, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-1.1293, dtype=torch.float64)
# I2
# tensor(0.5647, dtype=torch.float64)
# term1
# tensor(-0.0648, dtype=torch.float64)
# term2
# tensor(1.8817, dtype=torch.float64)
# I1
# tensor(-0.9085, dtype=torch.float64)
# term1
# tensor(0.1071, dtype=torch.float64)
# term2
# tensor(2.6623, dtype=torch.float64)
# I2
# tensor(-1.3847, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(2.0580, dtype=torch.float64)
# I1
# tensor(-1.0290, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.9207, dtype=torch.float64)
# I2
# tensor(-1.4603, dtype=torch.float64)
# term1
# tensor(0.0474, dtype=torch.float64)
# term2
# tensor(2.3741, dtype=torch.float64)
# I1
# tensor(-1.2107, dtype=torch.float64)
# term1
# tensor(0.1741, dtype=torch.float64)
# term2
# tensor(3.4124, dtype=torch.float64)
# I2
# tensor(-1.7932, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(0.7696, dtype=torch.float64)
# I1
# tensor(-0.3848, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(1.8747, dtype=torch.float64)
# I2
# tensor(-0.9373, dtype=torch.float64)
# term1
# tensor(-1.6298, dtype=torch.float64)
# term2
# tensor(-0.6668, dtype=torch.float64)
# I1
# tensor(1.1483, dtype=torch.float64)
# term1
# tensor(-1.6021, dtype=torch.float64)
# term2
# tensor(-0.5283, dtype=torch.float64)
# I2
# tensor(1.0652, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(1.7467, dtype=torch.float64)
# I1
# tensor(-0.8734, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.3816, dtype=torch.float64)
# I2
# tensor(-1.1908, dtype=torch.float64)
# term1
# tensor(0.7077, dtype=torch.float64)
# term2
# tensor(1.2389, dtype=torch.float64)
# I1
# tensor(-0.9733, dtype=torch.float64)
# term1
# tensor(0.8425, dtype=torch.float64)
# term2
# tensor(1.8586, dtype=torch.float64)
# I2
# tensor(-1.3506, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-1.8501, dtype=torch.float64)
# I1
# tensor(0.9250, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-0.9940, dtype=torch.float64)
# I2
# tensor(0.4970, dtype=torch.float64)
# term1
# tensor(-0.2928, dtype=torch.float64)
# term2
# tensor(-1.7535, dtype=torch.float64)
# I1
# tensor(1.0232, dtype=torch.float64)
# term1
# tensor(-0.2365, dtype=torch.float64)
# term2
# tensor(-0.9792, dtype=torch.float64)
# I2
# tensor(0.6079, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(1.9963, dtype=torch.float64)
# I1
# tensor(-0.9981, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(2.8523, dtype=torch.float64)
# I2
# tensor(-1.4262, dtype=torch.float64)
# term1
# tensor(-0.0015, dtype=torch.float64)
# term2
# tensor(0.9599, dtype=torch.float64)
# I1
# tensor(-0.4792, dtype=torch.float64)
# term1
# tensor(0.0894, dtype=torch.float64)
# term2
# tensor(1.8682, dtype=torch.float64)
# I2
# tensor(-0.9788, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(0.1452, dtype=torch.float64)
# I1
# tensor(-0.0726, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# tensor(1.1002, dtype=torch.float64)
# I2
# tensor(-0.5501, dtype=torch.float64)
# term1
# tensor(0.4549, dtype=torch.float64)
# term2
# tensor(1.3272, dtype=torch.float64)
# I1
# tensor(-0.8911, dtype=torch.float64)
# term1
# tensor(0.4765, dtype=torch.float64)
# term2
# tensor(1.6549, dtype=torch.float64)
# I2
# tensor(-1.0657, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-1.9997, dtype=torch.float64)
# I1
# tensor(0.9998, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(-1.5839, dtype=torch.float64)
# I2
# tensor(0.7920, dtype=torch.float64)
# term1
# tensor(-0.1867, dtype=torch.float64)
# term2
# tensor(0.0152, dtype=torch.float64)
# I1
# tensor(0.0857, dtype=torch.float64)
# term1
# tensor(0.0032, dtype=torch.float64)
# term2
# tensor(0.8750, dtype=torch.float64)
# I2
# tensor(-0.4391, dtype=torch.float64)
# term1
# tensor(-0., dtype=torch.float64)
# term2
# tensor(1.0700, dtype=torch.float64)
# I1
# tensor(-0.5350, dtype=torch.float64)
# term1
# tensor(0., dtype=torch.float64)
# term2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 117
#     113     return psi, phi
#     116 v_m = torch.from_numpy(v_m)
# --> 117 psi, phi = genCoords(v_c, f_c, v_m) #psi : for face's normal, phi: for vertex
#
# Cell In[12], line 99, in genCoords(V, T, v_m)
#      96 I[l] = GCTriInt(p, v[l%3], v[(l+1)%3], torch.zeros(3))
#      97 # print("I[l]")
#      98 # print(I[l])
# ---> 99 II[l] = GCTriInt(torch.zeros(3),  v[(l+1)%3], v[l%3], torch.zeros(3))
#     100 # print("II[l]")
#     101 # print(II[l])
#     102 q = torch.cross(v[(l+1)%3],  v[l%3])
#
# Cell In[12], line 48, in GCTriInt(p, v1, v2, eta)
#      46 print(2*torch.sqrt(c)*torch.atan(torch.sqrt(c)*C/d1))
#      47 print("term2")
# ---> 48 print(torch.sqrt(l)*torch.log(2*torch.sqrt(l)*(S**2)*(1-2*c*C/d2)/((1-C)**2)))
#      50 print("I2")
#      51 print(I2)
#
# File ~\anaconda3\envs\gc\lib\site-packages\torch\_tensor.py:427, in Tensor.__repr__(self, tensor_contents)
#     423     return handle_torch_function(
#     424         Tensor.__repr__, (self,), self, tensor_contents=tensor_contents
#     425     )
#     426 # All strings are unicode in Python 3.
# --> 427 return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#
# File ~\anaconda3\envs\gc\lib\site-packages\torch\_tensor_str.py:637, in _str(self, tensor_contents)
#     635 with torch.no_grad():
#     636     guard = torch._C._DisableFuncTorch()
# --> 637     return _str_intern(self, tensor_contents=tensor_contents)
#
# File ~\anaconda3\envs\gc\lib\site-packages\torch\_tensor_str.py:568, in _str_intern(inp, tensor_contents)
#     566                     tensor_str = _tensor_str(self.to_dense(), indent)
#     567                 else:
# --> 568                     tensor_str = _tensor_str(self, indent)
#     570 if self.layout != torch.strided:
#     571     suffixes.append("layout=" + str(self.layout))
#
# File ~\anaconda3\envs\gc\lib\site-packages\torch\_tensor_str.py:328, in _tensor_str(self, indent)
#     324     return _tensor_str_with_formatter(
#     325         self, indent, summarize, real_formatter, imag_formatter
#     326     )
#     327 else:
# --> 328     formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     329     return _tensor_str_with_formatter(self, indent, summarize, formatter)
#
# File ~\anaconda3\envs\gc\lib\site-packages\torch\_tensor_str.py:107, in _Formatter.__init__(self, tensor)
#     104 self.max_width = 1
#     106 with torch.no_grad():
# --> 107     tensor_view = tensor.reshape(-1)
#     109 if not self.floating_dtype:
#     110     for value in tensor_view:
#
# KeyboardInterrupt:

# %%
def gcTriInt(p, v1, v2, eta):
    cos_alpha =  ((v2-v1)@(p-v1)) / (np.linalg.norm(v2-v1)*np.linalg.norm(p-v1)) 
    cos_beta  =  ((v1-p)@(v2-p)) / (np.linalg.norm(v1-p)*np.linalg.norm(v2-p)) 
    if abs(cos_alpha) > (1 - EPS) or abs(cos_beta) > (1 - EPS): return 0
    #Calculate alpha
    alpha = np.arccos( cos_alpha )
    if abs(alpha - np.pi) < EPS or abs(alpha) < EPS: return 0
    #Calculate beta
    beta  = np.arccos( cos_beta )
    if abs(beta - np.pi) < EPS or abs(beta) < EPS: return 0
    
    l =  (np.linalg.norm(p-v1)**2)*(np.sin(alpha)**2)
    c = np.linalg.norm(p - eta)**2
    
    I = np.zeros(2)
    theta_list = [np.pi - alpha, np.pi - alpha - beta]
    for idx, theta in enumerate(theta_list):
        S = np.sin(theta)
        C = np.cos(theta)
        
        den1 = np.sqrt( l + c*S*S )
        den2 = c*(1+C)+l+np.sqrt(l)*np.sqrt(l+c*S*S)
        den3 = (1-C)**2
        
        I[idx] = -0.5*np.sign(S)*( 2*np.sqrt(c)*np.arctan((np.sqrt(c)*C)/den1) ) + np.sqrt(l)\
                * np.log(((np.sqrt(l)*(1-2*c*C/(den2))))*(2*S*S/(den3)))
    return (-1/(4*np.pi))*abs(I[0] - I[1] - np.sqrt(c)*beta)


def genCoords(V, T, delta):    
    phi = np.zeros( (len(V), len(delta)) )
    psi = np.zeros( (len(T), len(delta)) )
    len_delta = len(delta) # # of mesh vertices
    
    for eta_idx, eta in enumerate(delta):
        clear_output(wait=True)
        print(eta_idx+1,"/",len_delta," ", (eta_idx+1)/len_delta*100,"%")
        for j, face in enumerate(T):
            vj = face
            v = V[[vj[0], vj[1], vj[2]]] #하나의 face를 이루는 3개의 vertex 위치
            for l in range(3):
                v[l] -= eta # vector mesh vertex -> cage vertex
            p = (v[0]@n[j])*n[j]
            s =  np.zeros(3)
            I =  np.zeros(3)
            II = np.zeros(3)
            q  = np.zeros((3,3))
            N = np.zeros((3,3))
            for l in range(3):
                s[l]  = np.sign( np.cross(v[l] - p, v[(l+1)%3] - p)@n[j])
                I[l]  = gcTriInt(p, v[l], v[(l+1)%3], np.zeros(3))
                II[l] = gcTriInt(np.zeros(3), v[(l+1)%3], v[l], np.zeros(3))
                q[l] = np.cross(v[(l+1)%3], v[l])
                N[l] = q[l]/np.linalg.norm(q[l])
                if(np.linalg.norm(q[l]) < EPS1): II[l] = 0 
            I_tot = -abs( (s[0]*I[0]) + (s[1]*I[1]) + (s[2]*I[2]) )
            psi[j][eta_idx] = -I_tot
            w = n[j]*I_tot + N[0]*II[0] + N[1]*II[1] + N[2]*II[2]
            if np.linalg.norm(w) > 0.00001:
                for l in range(3):
                    phi[vj[l], eta_idx] += (N[(l+1)%3]@w)/(N[(l+1)%3]@v[l])
            
    return phi, psi

phi, psi = genCoords(v_c, f_c, v_m)
# Out:
# 40 / 772   5.181347150259067 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 65
#      61                     phi[vj[l], eta_idx] += (N[(l+1)%3]@w)/(N[(l+1)%3]@v[l])
#      63     return phi, psi
# ---> 65 phi, psi = genCoords(v_c, f_c, v_m)
#
# Cell In[34], line 52, in genCoords(V, T, delta)
#      50 s[l]  = np.sign( np.cross(v[l] - p, v[(l+1)%3] - p)@n[j])
#      51 I[l]  = gcTriInt(p, v[l], v[(l+1)%3], np.zeros(3))
# ---> 52 II[l] = gcTriInt(np.zeros(3), v[(l+1)%3], v[l], np.zeros(3))
#      53 q[l] = np.cross(v[(l+1)%3], v[l])
#      54 N[l] = q[l]/np.linalg.norm(q[l])
#
# Cell In[34], line 12, in gcTriInt(p, v1, v2, eta)
#       9 beta  = np.arccos( cos_beta )
#      10 if abs(beta - np.pi) < EPS or abs(beta) < EPS: return 0
# ---> 12 l =  (np.linalg.norm(p-v1)**2)*(np.sin(alpha)**2)
#      13 c = np.linalg.norm(p - eta)**2
#      15 I = np.zeros(2)
#
# File <__array_function__ internals>:180, in norm(*args, **kwargs)
#
# File ~\anaconda3\envs\gc\lib\site-packages\numpy\linalg\linalg.py:2516, in norm(x, ord, axis, keepdims)
#    2514     sqnorm = dot(x.real, x.real) + dot(x.imag, x.imag)
#    2515 else:
# -> 2516     sqnorm = dot(x, x)
#    2517 ret = sqrt(sqnorm)
#    2518 if keepdims:
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# print(phi[0])
print(psi[0])
# Out:
# [0.0182525  0.01847867 0.01689917 0.04360206 0.0407333  0.04981225
#  0.01318305 0.01310123 0.01319846 0.01870814 0.01912651 0.01954009
#  0.01856665 0.01867789 0.01367798 0.01338242 0.01341724 0.01327648
#  0.01723503 0.01853863 0.01671865 0.0146238  0.01482272 0.0142324
#  0.01563173 0.0156143  0.01546652 0.06159552 0.06425153 0.06826812
#  0.01632456 0.01687868 0.01679962 0.03412322 0.03192502 0.03008528
#  0.01680423 0.01784575 0.01747606 0.03547762 0.03365247 0.0361571
#  0.01441316 0.01400362 0.01417274 0.01411535 0.01379935 0.01366522
#  0.01526826 0.01509908 0.01493245 0.03649847 0.03775611 0.0152786
#  0.01539721 0.01537744 0.02872422 0.02590229 0.02884559 0.02592127
#  0.0259058  0.02854129 0.01907623 0.02092612 0.02135446 0.06770565
#  0.0127743  0.01290733 0.01282669 0.0194509  0.01960781 0.01478577
#  0.01533329 0.01489981 0.01457955 0.01466142 0.01561947 0.01407323
#  0.01413173 0.01362086 0.0545381  0.05274425 0.05763167 0.01473547
#  0.01415372 0.01498756 0.01485725 0.01516045 0.01521339 0.02001916
#  0.02081294 0.04222064 0.04580501 0.04388209 0.01602549 0.01609844
#  0.01599293 0.01431823 0.01419629 0.04270523 0.04470445 0.01374553
#  0.01356905 0.01398268 0.0290785  0.03056978 0.03005796 0.04474349
#  0.0263173  0.05932648 0.05796697 0.05399286 0.01547025 0.01531947
#  0.01478939 0.0151972  0.01460126 0.01582314 0.01596795 0.01569447
#  0.01357682 0.01360572 0.01365223 0.01538972 0.16174377 0.13697248
#  0.1322609  0.05048279 0.05466515 0.05815742 0.0155998  0.01499012
#  0.01511033 0.01334699 0.01312142 0.03554567 0.03924576 0.03544084
#  0.01507843 0.01506411 0.01514142 0.02384664 0.02468966 0.02246889
#  0.19169301 0.16280819 0.08069734 0.02970989 0.02910243 0.03854797
#  0.04200104 0.03445285 0.03377942 0.03174965 0.0153164  0.01541631
#  0.01502836 0.05369964 0.0584908  0.04931633 0.01617717 0.01576515
#  0.01596596 0.08422657 0.11070522 0.08400608 0.11113779 0.01926401
#  0.01506172 0.01486495 0.01458147 0.02986317 0.03141436 0.03432527
#  0.01353051 0.01410929 0.01427405 0.01709426 0.01663861 0.01771454
#  0.02684681 0.02826618 0.0138689  0.01353164 0.01381188 0.05849449
#  0.05186098 0.02562118 0.02469423 0.02193399 0.0255476  0.02348768
#  0.02361064 0.03663958 0.03484191 0.04049079 0.02652349 0.02907211
#  0.03172624 0.01482382 0.01302146 0.01316173 0.07973313 0.08025612
#  0.06714763 0.01619174 0.0157003  0.01482859 0.01574887 0.015522
#  0.01559375 0.03606137 0.03927922 0.01500961 0.01459621 0.01449761
#  0.01369272 0.01372505 0.01365013 0.05847864 0.06620422 0.06184449
#  0.02239057 0.01380436 0.01359853 0.01369011 0.01571814 0.01583662
#  0.03492423 0.03478725 0.01478138 0.01516342 0.01532598 0.02380697
#  0.02269796 0.02303394 0.04572692 0.07348221 0.0136696  0.01339528
#  0.0246578  0.023984   0.02202502 0.02764626 0.02480647 0.01580837
#  0.0157443  0.01602761 0.01497679 0.01438772 0.01488966 0.03173332
#  0.01312838 0.01610533 0.01713781 0.01818721 0.01641107 0.01437006
#  0.01404183 0.01376228 0.01495699 0.0151925  0.02549817 0.03013126
#  0.01414871 0.01467766 0.01491936 0.01407794 0.02068617 0.0204618
#  0.0523498  0.01363337 0.01406066 0.02215092 0.02280981 0.01311856
#  0.01301085 0.01875484 0.02085997 0.01937113 0.18001736 0.01592744
#  0.04692592 0.04967006 0.04997301 0.02863233 0.02133951 0.02063799
#  0.01580864 0.01587435 0.01627628 0.01617236 0.01721694 0.01380277
#  0.01337787 0.03783728 0.04280867 0.01572647 0.01579227 0.0158158
#  0.01636975 0.01613124 0.01638453 0.01583778 0.01564229 0.03218037
#  0.03317231 0.03267604 0.01296199 0.0128718  0.01354543 0.01358068
#  0.01361768 0.01549653 0.01529847 0.0157518  0.01592219 0.01458744
#  0.01402796 0.01510656 0.01384097 0.01560704 0.01559221 0.08680122
#  0.08641477 0.04811573 0.04161978 0.04900195 0.04800046 0.0153304
#  0.01552621 0.0157132  0.0148309  0.01441794 0.01356105 0.01407455
#  0.01381462 0.02186305 0.02070889 0.01386807 0.0141435  0.02849149
#  0.01597909 0.0160445  0.01680455 0.01622119 0.0220362  0.02154449
#  0.02065479 0.01529253 0.01464454 0.01452756 0.02507753 0.02374562
#  0.02530504 0.03160986 0.03232487 0.03245926 0.01318442 0.01578309
#  0.02691784 0.02444355 0.02594482 0.06888522 0.05886323 0.02499958
#  0.02888549 0.01597927 0.01459326 0.01456309 0.02770811 0.05093942
#  0.03137788 0.01495893 0.01527835 0.02975575 0.01544835 0.01570395
#  0.01583968 0.01610715 0.01613778 0.01628641 0.01461285 0.01465384
#  0.02385119 0.02045809 0.0395445  0.01597476 0.01572073 0.07240528
#  0.08266048 0.07432713 0.06411573 0.01585319 0.05410314 0.02078404
#  0.01990509 0.02220055 0.02007653 0.0218801  0.01591233 0.04547897
#  0.03878226 0.01553402 0.01568803 0.01600264 0.01554957 0.03307698
#  0.03484726 0.03723153 0.02999819 0.03109963 0.01577344 0.01564449
#  0.01612521 0.01526427 0.01441882 0.01413026 0.01344366 0.01344868
#  0.01421747 0.0140868  0.01298477 0.0349388  0.01417223 0.10877589
#  0.02227111 0.01945821 0.02311815 0.01477356 0.01420901 0.01504916
#  0.01591798 0.01597084 0.01386616 0.06756664 0.01545069 0.01521553
#  0.03056174 0.03049228 0.03394979 0.02690687 0.01384551 0.01358615
#  0.01533691 0.0147289  0.01418538 0.01413385 0.01406122 0.01305653
#  0.02410546 0.02528621 0.02165337 0.02349034 0.0185069  0.0140879
#  0.03547629 0.01445077 0.02336514 0.02261019 0.02511639 0.01478053
#  0.01458724 0.0141131  0.01439022 0.03081309 0.06004156 0.01333336
#  0.0127533  0.01326621 0.01579268 0.01572918 0.04709816 0.02235731
#  0.02359327 0.01554529 0.01600519 0.02794741 0.0154771  0.01334191
#  0.013466   0.01638079 0.01683629 0.01606689 0.01419496 0.01501363
#  0.01519394 0.01507028 0.01408444 0.01398786 0.01369898 0.01533339
#  0.01559598 0.01577874 0.01390804 0.01394419 0.0160176  0.01494125
#  0.01459891 0.20643602 0.20858596 0.02226757 0.02739666 0.02248295
#  0.01548686 0.01575156 0.01532492 0.01646675 0.01616448 0.01404953
#  0.01417389 0.01444299 0.0783437  0.06710049 0.01427411 0.01467678
#  0.01401481 0.02254592 0.02415917 0.02335984 0.02202276 0.02476154
#  0.0162708  0.01609194 0.01550504 0.01574257 0.01514168 0.01602826
#  0.01651796 0.01730856 0.01663602 0.01592498 0.02981007 0.03196787
#  0.0152761  0.03312142 0.03262642 0.03105246 0.02590567 0.02475391
#  0.03358137 0.03383906 0.01484042 0.01409367 0.01501103 0.0144689
#  0.01514376 0.01535898 0.01429955 0.01534514 0.01483704 0.01309125
#  0.01307493 0.01268106 0.0212883  0.01927029 0.02231935 0.03254038
#  0.03374174 0.014476   0.01437724 0.01373096 0.01471819 0.0333901
#  0.0159855  0.09053831 0.1009314  0.01568758 0.01575177 0.01582697
#  0.01371674 0.01353633 0.01349363 0.09691903 0.01354866 0.01569868
#  0.01586248 0.02801259 0.03073343 0.02117981 0.02213213 0.01346757
#  0.10210969 0.0784481  0.09260438 0.01513916 0.01512727 0.01514366
#  0.01329524 0.0228851  0.05630924 0.0518984  0.02586025 0.01310073
#  0.01338983 0.02561291 0.01610948 0.01579901 0.01621994 0.02429643
#  0.01329856 0.01353008 0.02996563 0.02854878 0.03068763 0.01571838
#  0.01536267 0.03911619 0.03653768 0.01444901 0.0134036  0.03063432
#  0.01586954 0.01564644 0.01822996 0.01387477 0.01379204 0.1863346
#  0.01311945 0.02459862 0.02355853 0.06341314 0.01369214 0.02671948
#  0.01608063 0.01429595 0.01620211 0.01637035 0.01378907 0.01863417
#  0.01814146 0.01449454 0.10646348 0.10634669 0.01480619 0.02581691
#  0.01366356 0.01490586 0.01378756 0.01526526 0.01586248 0.01564758
#  0.026765   0.02620444 0.01559744 0.01603132 0.01613592 0.01575861
#  0.01663987 0.017211   0.0164655  0.0162603  0.01635465 0.01574737
#  0.02421165 0.06579234 0.03026677 0.02758074 0.02044365 0.01562553
#  0.02321012 0.02316722 0.02408405 0.03340117 0.03254783 0.03312461
#  0.01596732 0.01561261 0.01497047 0.01598648 0.0342974  0.01446503
#  0.01565178 0.01591784 0.01589542 0.01555646 0.09633252 0.015547
#  0.01513461 0.0223819  0.01579142 0.02463934 0.02044043 0.03212655
#  0.0342008  0.01310415 0.01419636 0.02144386 0.01571854 0.01584768
#  0.01569716 0.01598063 0.01625526 0.02669065 0.02409298 0.12816311
#  0.13846271 0.15634254 0.01623985 0.01452356 0.01291416 0.01560891
#  0.0688214  0.01404943 0.01606703 0.01580569 0.01378361 0.01593979
#  0.01580525 0.01608129 0.01325234 0.08161461 0.20798473 0.10868044
#  0.08029394 0.01542199 0.01320177 0.03799141 0.01545358 0.01507859
#  0.03089241 0.02025471 0.01546706 0.01526991 0.05220861 0.0134119
#  0.03138108 0.0763295  0.04799135 0.06594258 0.07386866 0.0135439
#  0.01322507 0.06314026 0.01557976 0.01471478 0.01386284 0.01363381
#  0.07028099 0.14083542 0.1645405  0.03293451 0.01964115 0.01510976
#  0.01552659 0.01659526 0.01661236 0.01652058 0.01472582 0.01594486
#  0.01651901 0.01598315 0.0161106  0.01584272 0.01389712 0.01584641
#  0.01560899 0.0158313  0.0161501  0.01611972 0.01619534 0.01620356
#  0.01595835 0.01604036 0.01585267 0.02689356 0.01395605 0.0140318
#  0.01384628 0.0138915  0.01446883 0.01407022]
